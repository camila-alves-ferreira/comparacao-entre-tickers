# %% [markdown]
# <a href="https://colab.research.google.com/github/camila-alves-ferreira/comparacao-entre-tickers/blob/main/analise_tickets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Introdução

# %% [markdown]
# A análise abaixo foi feita utilizando dados do Yahoo Finance. A motivação é observar alguns comportamentos de dois dos tickets de maior participação do índice S&P 500, que representam uma participação de 14% do índice geral - MSFT (Microsoft) e AAPL (Apple).

# %% [markdown]
# Fonte de dados: https://finance.yahoo.com/

# %% [markdown]
# # 1. Instalação e Importação das Bibliotecas

# %% [markdown]
# Primeiramente utilizaremos a biblioteca yfinance para baixar os dados históricos:

# %%
# !pip install yfinance

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Análise

# %% [markdown]
# Vamos carregar os dados da ação Microsoft.

# %%
msft = yf.Ticker("MSFT")

# %% [markdown]
# Podemos observar os preços de fechamento com intervalo de uma semana ao longo do ano de 2023 para o ticker MSFT:

# %%
msft_price = yf.download("MSFT", start="2023-01-01", end="2023-12-31", interval="1wk")["Close"]
msft_price
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2023-01-01    224.929993
# 2023-01-08    239.229996
# 2023-01-15    240.220001
# 2023-01-22    248.160004
# 2023-01-29    258.350006
# 2023-02-05    263.100006
# 2023-02-12    258.059998
# 2023-02-19    249.220001
# 2023-02-26    255.289993
# 2023-03-05    248.589996
# 2023-03-12    279.429993
# 2023-03-19    280.570007
# 2023-03-26    288.299988
# 2023-04-02    291.600006
# 2023-04-09    286.140015
# 2023-04-16    285.760010
# 2023-04-23    307.260010
# 2023-04-30    310.649994
# 2023-05-07    308.970001
# 2023-05-14    318.339996
# 2023-05-21    332.890015
# 2023-05-28    335.399994
# 2023-06-04    326.790009
# 2023-06-11    342.329987
# 2023-06-18    335.019989
# 2023-06-25    340.540009
# 2023-07-02    337.220001
# 2023-07-09    345.239990
# 2023-07-16    343.769989
# 2023-07-23    338.369995
# 2023-07-30    327.779999
# 2023-08-06    321.010010
# 2023-08-13    316.480011
# 2023-08-20    322.980011
# ...

# %% [markdown]
# Os preços da ação podem ser visualizados de maneira mais clara em um dataframe:

# %%
df_msft_price = pd.DataFrame(msft_price)
df_msft_price
# Out:
#                  Close
# Date
# 2023-01-01  224.929993
# 2023-01-08  239.229996
# 2023-01-15  240.220001
# 2023-01-22  248.160004
# 2023-01-29  258.350006
# 2023-02-05  263.100006
# 2023-02-12  258.059998
# 2023-02-19  249.220001
# 2023-02-26  255.289993
# 2023-03-05  248.589996
# 2023-03-12  279.429993
# 2023-03-19  280.570007
# 2023-03-26  288.299988
# 2023-04-02  291.600006
# 2023-04-09  286.140015
# 2023-04-16  285.760010
# 2023-04-23  307.260010
# 2023-04-30  310.649994
# 2023-05-07  308.970001
# 2023-05-14  318.339996
# 2023-05-21  332.890015
# 2023-05-28  335.399994
# 2023-06-04  326.790009
# 2023-06-11  342.329987
# 2023-06-18  335.019989
# 2023-06-25  340.540009
# 2023-07-02  337.220001
# 2023-07-09  345.239990
# 2023-07-16  343.769989
# 2023-07-23  338.369995
# 2023-07-30  327.779999
# 2023-08-06  321.010010
# 2023-08-13  316.480011
# 2023-08-20  322.980011
# 2023-08-27  328.660004
# 2023-09-03  334.269989
# 2023-09-10  330.220001
# 2023-09-17  317.010010
# ...

# %%
msft.info
# Out:
# {'address1': 'One Microsoft Way',
#  'city': 'Redmond',
#  'state': 'WA',
#  'zip': '98052-6399',
#  'country': 'United States',
#  'phone': '425 882 8080',
#  'website': 'https://www.microsoft.com',
#  'industry': 'Software - Infrastructure',
#  'industryKey': 'software-infrastructure',
#  'industryDisp': 'Software - Infrastructure',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %% [markdown]
# O pagamento de dividendos dos últimos dez anos de MSFT pode ser observado no dataframe abaixo:

# %%
msft_dividends = yf.download("MSFT", start="2013-01-01", end="2023-12-31", actions=True)['Dividends']
msft_dividends
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2013-01-02    0.0
# 2013-01-03    0.0
# 2013-01-04    0.0
# 2013-01-07    0.0
# 2013-01-08    0.0
#              ...
# 2023-12-22    0.0
# 2023-12-26    0.0
# 2023-12-27    0.0
# 2023-12-28    0.0
# 2023-12-29    0.0
# Name: Dividends, Length: 2768, dtype: float64

# %%
df_msft_dividends = pd.DataFrame(msft_dividends)
df_msft_dividends
# Out:
#             Dividends
# Date
# 2013-01-02        0.0
# 2013-01-03        0.0
# 2013-01-04        0.0
# 2013-01-07        0.0
# 2013-01-08        0.0
# ...               ...
# 2023-12-22        0.0
# 2023-12-26        0.0
# 2023-12-27        0.0
# 2023-12-28        0.0
# 2023-12-29        0.0
#
# [2768 rows x 1 columns]

# %% [markdown]
# Vamos carregar dados também para Apple (AAPL).

# %%
aapl = yf.Ticker("AAPL")

# %% [markdown]
# Podemos observar os preços de fechamento com intervalo de uma semana ao longo do ano de 2023 para o ticker AAPL:

# %%
aapl_price = yf.download("AAPL", start = "2023-01-01", end = "2023-12-31", interval= "1wk")["Close"]
aapl_price
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2023-01-01    129.619995
# 2023-01-08    134.759995
# 2023-01-15    137.869995
# 2023-01-22    145.929993
# 2023-01-29    154.500000
# 2023-02-05    151.009995
# 2023-02-12    152.550003
# 2023-02-19    146.710007
# 2023-02-26    151.029999
# 2023-03-05    148.500000
# 2023-03-12    155.000000
# 2023-03-19    160.250000
# 2023-03-26    164.899994
# 2023-04-02    164.660004
# 2023-04-09    165.210007
# 2023-04-16    165.020004
# 2023-04-23    169.679993
# 2023-04-30    173.570007
# 2023-05-07    172.570007
# 2023-05-14    175.160004
# 2023-05-21    175.429993
# 2023-05-28    180.949997
# 2023-06-04    180.960007
# 2023-06-11    184.919998
# 2023-06-18    186.679993
# 2023-06-25    193.970001
# 2023-07-02    190.679993
# 2023-07-09    190.690002
# 2023-07-16    191.940002
# 2023-07-23    195.830002
# 2023-07-30    181.990005
# 2023-08-06    177.789993
# 2023-08-13    174.490005
# 2023-08-20    178.610001
# ...

# %% [markdown]
# Os preços da ação podem ser visualizados de maneira mais clara em um dataframe:

# %%
df_aapl_price = pd.DataFrame(aapl_price)
df_aapl_price
# Out:
#                  Close
# Date
# 2023-01-01  129.619995
# 2023-01-08  134.759995
# 2023-01-15  137.869995
# 2023-01-22  145.929993
# 2023-01-29  154.500000
# 2023-02-05  151.009995
# 2023-02-12  152.550003
# 2023-02-19  146.710007
# 2023-02-26  151.029999
# 2023-03-05  148.500000
# 2023-03-12  155.000000
# 2023-03-19  160.250000
# 2023-03-26  164.899994
# 2023-04-02  164.660004
# 2023-04-09  165.210007
# 2023-04-16  165.020004
# 2023-04-23  169.679993
# 2023-04-30  173.570007
# 2023-05-07  172.570007
# 2023-05-14  175.160004
# 2023-05-21  175.429993
# 2023-05-28  180.949997
# 2023-06-04  180.960007
# 2023-06-11  184.919998
# 2023-06-18  186.679993
# 2023-06-25  193.970001
# 2023-07-02  190.679993
# 2023-07-09  190.690002
# 2023-07-16  191.940002
# 2023-07-23  195.830002
# 2023-07-30  181.990005
# 2023-08-06  177.789993
# 2023-08-13  174.490005
# 2023-08-20  178.610001
# 2023-08-27  189.460007
# 2023-09-03  178.179993
# 2023-09-10  175.009995
# 2023-09-17  174.789993
# ...

# %% [markdown]
# Para obter a lista de informações do ticker deve-se usar o comando info:

# %%
aapl.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
aapl_dividends = yf.download("AAPL", start="2013-01-01", end="2023-12-31", actions=True)['Dividends']
aapl_dividends
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2013-01-02    0.0
# 2013-01-03    0.0
# 2013-01-04    0.0
# 2013-01-07    0.0
# 2013-01-08    0.0
#              ...
# 2023-12-22    0.0
# 2023-12-26    0.0
# 2023-12-27    0.0
# 2023-12-28    0.0
# 2023-12-29    0.0
# Name: Dividends, Length: 2768, dtype: float64

# %% [markdown]
# O pagamento de dividendos dos últimos dez anos de AAPL pode ser observado no dataframe abaixo:

# %%
df_aapl_dividends = pd.DataFrame(msft_dividends)
df_aapl_dividends
# Out:
#             Dividends
# Date
# 2013-01-02        0.0
# 2013-01-03        0.0
# 2013-01-04        0.0
# 2013-01-07        0.0
# 2013-01-08        0.0
# ...               ...
# 2023-12-22        0.0
# 2023-12-26        0.0
# 2023-12-27        0.0
# 2023-12-28        0.0
# 2023-12-29        0.0
#
# [2768 rows x 1 columns]

# %% [markdown]
# # 3. Comparação entre os tickets

# %% [markdown]
# Através de gráficos podemos ter uma visualização e melhor compreensão dos dados. Nos gráficos abaixo são feitas comparações de parâmetros já analisados como preço de fechamento ao longo de 2023 e dividendos dos últimos dez anos.

# %%
plt.plot(msft_price, label="MSFT")
plt.plot(aapl_price, label = "AAPL")
plt.xlabel("Mês")
plt.ylabel("Preço em US$")
plt.legend()
plt.show()

# %%
msft_dividends = yf.download("MSFT", start = "2013-01-01", end = "2023-12-31", actions=True)['Dividends']
msft_dividends
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2013-01-02    0.0
# 2013-01-03    0.0
# 2013-01-04    0.0
# 2013-01-07    0.0
# 2013-01-08    0.0
#              ...
# 2023-12-22    0.0
# 2023-12-26    0.0
# 2023-12-27    0.0
# 2023-12-28    0.0
# 2023-12-29    0.0
# Name: Dividends, Length: 2768, dtype: float64

# %%
aapl_dividends = yf.download("AAPL", start = "2013-01-01", end = "2023-12-31", actions=True)['Dividends']
aapl_dividends
# Out:
# [*********************100%%**********************]  1 of 1 completed
# Date
# 2013-01-02    0.0
# 2013-01-03    0.0
# 2013-01-04    0.0
# 2013-01-07    0.0
# 2013-01-08    0.0
#              ...
# 2023-12-22    0.0
# 2023-12-26    0.0
# 2023-12-27    0.0
# 2023-12-28    0.0
# 2023-12-29    0.0
# Name: Dividends, Length: 2768, dtype: float64

# %% [markdown]
# A Microsoft frente à Apple se apresenta como uma melhor pagadora de dividendos num longo prazo.

# %%
plt.plot(msft_dividends, label="MSFT", color="tomato")
plt.plot(aapl_dividends, label="AAPL", color="teal")
plt.title("Dividendos de MSFT e AAPL de 2013 a 2023")
plt.xlabel("Ano")
plt.ylabel("Dividendos em US$")
plt.legend()
plt.show()

# %%
msft.info['marketCap']
# Out:
# 3064490098688

# %%
aapl.info['marketCap']
# Out:
# 2830214889472

# %% [markdown]
# Pela comparação do market cap podemos verificar que pela primeira vez em mais de 2 anos, a Microsoft se configura como a empresa de maior valor de mercado do mundo atualmente. O investimento direcionado da empresa em desenvolvimento de soluções com foco em inteligência artificial se mostrou uma decisão acertada, pois ajudou a impulsionar de maneira favorável o crescimento recente da Microsoft e superação em valor de mercado frente à gigante Apple.

# %% [markdown]
# # 4. Referências

# %% [markdown]
# https://www.bloomberglinea.com.br/mercados/como-a-microsoft-superou-a-apple-e-se-tornou-a-empresa-com-o-maior-valor-de-mercado/#:~:text=Microsoft%20e%20Apple%20continuam%20sendo,se%20aproximam%20de%20seu%20tamanho.
